# %% [markdown]
# # __Electric Vehicle Charging Stations in Vancouver__
# ___

# %% [markdown]
# ### __Data Source__
# [City of Vancouver - Open Data Catalogue](http://data.vancouver.ca/datacatalogue/electricVehicleChargingStations.htm)

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('ftp://webftp.vancouver.ca/OpenData/csv/electric_vehicle_charging_stations.csv')
df.head(5)
# Out:
#     LATITUDE   LONGITUDE                   LOT_OPERATOR  \
# 0  49.222496 -123.100262              City of Vancouver
# 1  49.290400 -123.137100                  Easy Park Lot
# 2  49.262481 -123.113686                  Easy Park Lot
# 3  49.290288 -123.125469  Coal Harbour Community Centre
# 4  49.243656 -123.106549                            CoV
#
#                     ADDRESS
# 0          6810 Main Street
# 1             900 Denman St
# 2         455 West 10th Ave
# 3      480 Broughton Street
# 4  4575 Clancy Loranger Way

# %% [markdown]
# ### __Number of Charging Stations By Operator__
#
# ---

# %%
df['LOT_OPERATOR'].value_counts()
# Out:
# City of Vancouver                4
# Easy Park Lot                    3
# Easypark                         3
# Ivanhoe Cambridge                3
# Easy Park / Park Board           3
# VSB                              2
# Jericho Village                  1
# Pacific National Exhibition      1
# BCIT / Impark                    1
# Vancouver General Hospital       1
# Impark                           1
# Telus / Retailer                 1
# Vancouver Aquarium               1
# ASQ Building Ltd                 1
# Coal Harbour Community Centre    1
# Canadian Tire                    1
# Canada Place                     1
# Best Western                     1
# CoV                              1
# Name: LOT_OPERATOR, dtype: int64

# %% [markdown]
# ### __Map-View of Charging Stations__
# ---

# %%
import folium
from folium.plugins import MarkerCluster

# %%
# Central point of the map 
location = np.mean(df['LATITUDE']), np.mean(df['LONGITUDE'])
location
# Out:
# (49.268486408357276, -123.11674586604052)

# %%
locationlist = df[['LATITUDE', 'LONGITUDE']].values.tolist()
labels = df['ADDRESS']


map = folium.Map(location = location, 
                 zoom_start=12,
                tiles = 'Stamen Toner')

marker_cluster = MarkerCluster().add_to(map)

for point in range(len(locationlist)):
                  popup = folium.Popup(labels[point], parse_html = True)
                  folium.Marker(locationlist[point], 
                                popup=popup, 
                               icon = folium.Icon(color = 'black', icon='fas fa-plug', prefix='fa')).add_to(marker_cluster)
display(map)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
